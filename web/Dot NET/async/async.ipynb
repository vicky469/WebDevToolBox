# %%
using System.Threading;
using System.Threading.Tasks;
for (int i = 0; i < 1000; i++)
{
    WaitCallback waitCallback = _ =>
    {

        Thread.Sleep(1000); // to simiulate some work being done
        Console.WriteLine($"i: {i} .Thread {Thread.CurrentThread.ManagedThreadId} is running");
    };
    ThreadPool.QueueUserWorkItem(waitCallback);
}

// it will print i: 1000 1000 times when I am expecting it to print incredental numbers.
// solution: instead of use the variable i directly which is going to be reused across all of the closures, create a local variable inside the loop and use that variable inside the lambda function.
# Out:
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 3 is running
# i: 1000 .Thread 46 is running
# i: 1000 .Thread 47 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 46 is running
# i: 1000 .Thread 47 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 3 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 47 is running
# i: 1000 .Thread 46 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 3 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 46 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 47 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 3 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 47 is running
# i: 1000 .Thread 46 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 3 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 46 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 47 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 3 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 46 is running
# i: 1000 .Thread 3 is running
# i: 1000 .Thread 6 is running
# i: 1000 .Thread 4 is running
# i: 1000 .Thread 23 is running
# i: 1000 .Thread 25 is running
# i: 1000 .Thread 47 is running
# i: 1000 .Thread 7 is running
# i: 1000 .Thread 22 is running
# i: 1000 .Thread 27 is running
# i: 1000 .Thread 12 is running
# i: 1000 .Thread 24 is running
# i: 1000 .Thread 26 is running
# i: 1000 .Thread 15 is running
# i: 1000 .Thread 32 is running
# i: 1000 .Thread 41 is running
# i: 1000 .Thread 42 is running
# i: 1000 .Thread 40 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 35 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 30 is running
# i: 1000 .Thread 34 is running
# i: 1000 .Thread 38 is running
# i: 1000 .Thread 37 is running
# i: 1000 .Thread 44 is running
# i: 1000 .Thread 43 is running
# i: 1000 .Thread 31 is running
# i: 1000 .Thread 33 is running
# i: 1000 .Thread 36 is running
# i: 1000 .Thread 29 is running
# i: 1000 .Thread 28 is running
# i: 1000 .Thread 45 is running
# i: 1000 .Thread 39 is running
# i: 1000 .Thread 35 is running

# %%
using System;
using System.Collections.Concurrent;
using System.Threading;
using System.Threading.Tasks;

for (int i = 0; i < 1000; i++)
{
    int capturedValue = i; // Create a local variable and assign the value of i to it. 
    // Every work in the queue will have its own copy of the capturedValue

    MyThreadPool.QueueUserWorkItem(delegate{
        Thread.Sleep(1000);
        Console.WriteLine($"i: {capturedValue}. Thread {Thread.CurrentThread.ManagedThreadId} is running");
    });
}

static class MyThreadPool
{
    private static readonly BlockingCollection<Action> s_workItems = new ();
    // to store things in the concurrent queue but when I want to that I want to block the thread until there is something to do.
    // the threads in the tread pool are going to try to take things from the queue to process it, if nothing is there just wait 
    public static void QueueUserWorkItem(Action action)
    {
        s_workItems.Add(action);
    }
    static MyThreadPool()
    {
        for (int i = 0; i < Environment.ProcessorCount; i++)
        {
            new Thread(()=> {}).Start();
        }
    }
}
# Out:
# i: 0. Thread 60 is running
# i: 3. Thread 62 is running
# i: 7. Thread 66 is running
# i: 5. Thread 64 is running
# i: 2. Thread 61 is running
# i: 4. Thread 63 is running
# i: 6. Thread 65 is running
# i: 9. Thread 68 is running
# i: 8. Thread 67 is running
# i: 1. Thread 57 is running
# i: 10. Thread 69 is running
# i: 11. Thread 70 is running
# i: 15. Thread 64 is running
# i: 14. Thread 66 is running
# i: 12. Thread 60 is running
# i: 16. Thread 61 is running
# i: 17. Thread 63 is running
# i: 18. Thread 65 is running
# i: 19. Thread 68 is running
# i: 20. Thread 67 is running
# i: 21. Thread 57 is running
# i: 13. Thread 62 is running
# i: 22. Thread 69 is running
# i: 23. Thread 70 is running
# i: 24. Thread 64 is running
# i: 25. Thread 66 is running
# i: 28. Thread 63 is running
# i: 32. Thread 57 is running
# i: 30. Thread 68 is running
# i: 31. Thread 67 is running
# i: 26. Thread 60 is running
# i: 33. Thread 62 is running
# i: 29. Thread 65 is running
# i: 27. Thread 61 is running
# i: 34. Thread 69 is running
# i: 35. Thread 70 is running
# i: 40. Thread 68 is running
# i: 41. Thread 67 is running
# i: 39. Thread 57 is running
# i: 42. Thread 60 is running
# i: 36. Thread 64 is running
# i: 37. Thread 66 is running
# i: 38. Thread 63 is running
# i: 45. Thread 61 is running
# i: 43. Thread 62 is running
# i: 44. Thread 65 is running
# i: 46. Thread 69 is running
# i: 47. Thread 70 is running
# i: 51. Thread 60 is running
# i: 48. Thread 67 is running
# i: 49. Thread 57 is running
# i: 50. Thread 68 is running
# i: 52. Thread 64 is running
# i: 54. Thread 63 is running
# i: 53. Thread 66 is running
# i: 56. Thread 62 is running
# i: 55. Thread 61 is running
# i: 57. Thread 65 is running
# i: 58. Thread 69 is running
# i: 59. Thread 60 is running
# i: 64. Thread 63 is running
# i: 65. Thread 66 is running
# i: 66. Thread 62 is running
# i: 60. Thread 67 is running
# i: 62. Thread 68 is running
# i: 61. Thread 57 is running
# i: 63. Thread 64 is running
# i: 68. Thread 65 is running
# i: 67. Thread 61 is running
# i: 69. Thread 69 is running
# i: 70. Thread 70 is running
# i: 72. Thread 63 is running
# i: 73. Thread 66 is running
# i: 71. Thread 60 is running
# i: 74. Thread 62 is running
# i: 75. Thread 67 is running
# i: 76. Thread 68 is running
# i: 78. Thread 64 is running
# i: 79. Thread 65 is running
# i: 77. Thread 57 is running
# i: 80. Thread 61 is running
# i: 81. Thread 69 is running
# i: 82. Thread 70 is running
# i: 83. Thread 63 is running
# i: 84. Thread 66 is running
# i: 85. Thread 60 is running
# i: 86. Thread 62 is running
# i: 87. Thread 67 is running
# i: 89. Thread 64 is running
# i: 90. Thread 65 is running
# i: 88. Thread 68 is running
# i: 91. Thread 57 is running
# i: 92. Thread 61 is running
# i: 93. Thread 69 is running
# i: 94. Thread 70 is running
# i: 95. Thread 66 is running
# i: 96. Thread 63 is running
# i: 97. Thread 60 is running
# i: 98. Thread 62 is running
# i: 99. Thread 67 is running
# i: 100. Thread 64 is running
# i: 101. Thread 65 is running
# i: 102. Thread 68 is running
# i: 103. Thread 57 is running
# i: 104. Thread 61 is running
# i: 105. Thread 69 is running
# i: 106. Thread 70 is running
# i: 110. Thread 62 is running
# i: 108. Thread 66 is running
# i: 107. Thread 63 is running
# i: 109. Thread 60 is running
# i: 115. Thread 57 is running
# i: 114. Thread 68 is running
# i: 111. Thread 67 is running
# i: 113. Thread 65 is running
# i: 112. Thread 64 is running
# i: 116. Thread 61 is running
# i: 117. Thread 69 is running
# i: 118. Thread 70 is running
# i: 119. Thread 62 is running
# i: 120. Thread 66 is running
# i: 121. Thread 63 is running
# i: 122. Thread 60 is running
# i: 123. Thread 57 is running
# i: 125. Thread 67 is running
# i: 124. Thread 68 is running
# i: 127. Thread 64 is running
# i: 126. Thread 65 is running
# i: 128. Thread 61 is running
# i: 129. Thread 69 is running
# i: 130. Thread 70 is running
# i: 131. Thread 62 is running
# i: 138. Thread 64 is running
# i: 132. Thread 66 is running
# i: 140. Thread 61 is running
# i: 133. Thread 63 is running
# i: 134. Thread 60 is running
# i: 135. Thread 57 is running
# i: 136. Thread 67 is running
# i: 137. Thread 68 is running
# i: 139. Thread 65 is running
# i: 141. Thread 69 is running
# i: 142. Thread 70 is running
# i: 144. Thread 64 is running
# i: 145. Thread 66 is running
# i: 146. Thread 61 is running
# i: 147. Thread 63 is running
# i: 148. Thread 60 is running
# i: 149. Thread 57 is running
# i: 150. Thread 67 is running
# i: 151. Thread 68 is running
# i: 152. Thread 65 is running
# i: 143. Thread 62 is running
# i: 153. Thread 69 is running
# i: 154. Thread 70 is running
# i: 155. Thread 64 is running
# i: 156. Thread 66 is running
# i: 157. Thread 61 is running
# i: 158. Thread 63 is running
# i: 159. Thread 60 is running
# i: 160. Thread 57 is running
# i: 161. Thread 67 is running
# i: 162. Thread 68 is running
# i: 163. Thread 65 is running
# i: 164. Thread 62 is running
# i: 165. Thread 69 is running
# i: 166. Thread 70 is running
# i: 167. Thread 64 is running
# i: 168. Thread 66 is running
# i: 169. Thread 61 is running
# i: 173. Thread 67 is running
# i: 176. Thread 62 is running
# i: 170. Thread 63 is running
# i: 171. Thread 60 is running
# i: 172. Thread 57 is running
# i: 174. Thread 68 is running
# i: 175. Thread 65 is running
# i: 177. Thread 69 is running
# i: 178. Thread 70 is running
# i: 179. Thread 64 is running
# i: 180. Thread 66 is running
# i: 182. Thread 67 is running
# i: 184. Thread 63 is running
# i: 185. Thread 60 is running
# i: 187. Thread 68 is running
# i: 188. Thread 65 is running
# i: 183. Thread 62 is running
# i: 181. Thread 61 is running
# i: 186. Thread 57 is running
# i: 189. Thread 69 is running
# i: 190. Thread 70 is running
# i: 192. Thread 66 is running
# i: 193. Thread 67 is running
# i: 191. Thread 64 is running
# i: 196. Thread 68 is running
# i: 195. Thread 60 is running
# i: 197. Thread 65 is running
# i: 200. Thread 57 is running
# i: 198. Thread 62 is running
# i: 194. Thread 63 is running
# i: 199. Thread 61 is running
# i: 201. Thread 69 is running
# i: 202. Thread 70 is running
# i: 204. Thread 67 is running
# i: 210. Thread 62 is running
# i: 212. Thread 61 is running
# i: 205. Thread 64 is running
# i: 206. Thread 68 is running
# i: 207. Thread 60 is running
# i: 208. Thread 65 is running
# i: 211. Thread 63 is running
# i: 203. Thread 66 is running
# i: 209. Thread 57 is running
# i: 213. Thread 69 is running
# i: 214. Thread 70 is running
# i: 217. Thread 72 is running
# i: 215. Thread 48 is running
# i: 216. Thread 71 is running
# i: 218. Thread 73 is running
# i: 219. Thread 75 is running
# i: 221. Thread 77 is running
# i: 220. Thread 76 is running
# i: 222. Thread 78 is running
# i: 224. Thread 80 is running
# i: 225. Thread 81 is running
# i: 223. Thread 79 is running
# i: 227. Thread 83 is running
# i: 226. Thread 82 is running
# i: 228. Thread 84 is running
# i: 231. Thread 87 is running
# i: 229. Thread 85 is running
# i: 230. Thread 86 is running
# i: 234. Thread 90 is running
# i: 233. Thread 89 is running
# i: 232. Thread 88 is running
# i: 235. Thread 67 is running
# i: 237. Thread 61 is running
# i: 238. Thread 64 is running
# i: 239. Thread 68 is running
# i: 245. Thread 69 is running
# i: 236. Thread 62 is running
# i: 240. Thread 60 is running
# i: 243. Thread 66 is running
# i: 241. Thread 65 is running
# i: 242. Thread 63 is running
# i: 244. Thread 57 is running
# i: 246. Thread 70 is running
# i: 251. Thread 75 is running
# i: 253. Thread 76 is running
# i: 265. Thread 89 is running
# i: 249. Thread 71 is running
# i: 250. Thread 73 is running
# i: 247. Thread 72 is running
# i: 248. Thread 48 is running
# i: 252. Thread 77 is running
# i: 255. Thread 80 is running
# i: 254. Thread 78 is running
# i: 256. Thread 81 is running
# i: 259. Thread 82 is running
# i: 257. Thread 79 is running
# i: 260. Thread 84 is running
# i: 258. Thread 83 is running
# i: 266. Thread 88 is running
# i: 262. Thread 85 is running
# i: 261. Thread 87 is running
# i: 263. Thread 86 is running
# i: 264. Thread 90 is running
# i: 267. Thread 67 is running
# i: 269. Thread 64 is running
# i: 268. Thread 61 is running
# i: 270. Thread 68 is running
# i: 277. Thread 57 is running
# i: 271. Thread 69 is running
# i: 273. Thread 60 is running
# i: 272. Thread 62 is running
# i: 275. Thread 65 is running
# i: 274. Thread 66 is running
# i: 276. Thread 63 is running
# i: 280. Thread 76 is running
# i: 285. Thread 72 is running
# i: 278. Thread 70 is running
# i: 279. Thread 75 is running
# i: 287. Thread 77 is running
# i: 286. Thread 48 is running
# i: 289. Thread 78 is running
# i: 281. Thread 89 is running
# i: 288. Thread 80 is running
# i: 284. Thread 73 is running
# i: 282. Thread 91 is running
# i: 283. Thread 71 is running
# i: 298. Thread 86 is running
# i: 290. Thread 81 is running
# i: 291. Thread 82 is running
# i: 292. Thread 79 is running
# i: 296. Thread 85 is running
# i: 297. Thread 87 is running
# i: 293. Thread 84 is running
# i: 294. Thread 83 is running
# i: 295. Thread 88 is running
# i: 299. Thread 90 is running
# i: 300. Thread 67 is running
# i: 301. Thread 64 is running
# i: 302. Thread 61 is running
# i: 303. Thread 68 is running
# i: 305. Thread 69 is running
# i: 304. Thread 57 is running
# i: 307. Thread 62 is running
# i: 306. Thread 60 is running
# i: 310. Thread 63 is running
# i: 308. Thread 65 is running
# i: 309. Thread 66 is running
# i: 318. Thread 89 is running
# i: 311. Thread 76 is running
# i: 313. Thread 70 is running
# i: 320. Thread 73 is running
# i: 319. Thread 80 is running
# i: 321. Thread 91 is running
# i: 312. Thread 72 is running
# i: 316. Thread 48 is running
# i: 314. Thread 75 is running
# i: 315. Thread 77 is running
# i: 317. Thread 78 is running
# i: 322. Thread 71 is running
# i: 330. Thread 83 is running
# i: 328. Thread 87 is running
# i: 327. Thread 85 is running
# i: 323. Thread 86 is running
# i: 331. Thread 88 is running
# i: 324. Thread 81 is running
# i: 325. Thread 82 is running
# i: 326. Thread 79 is running
# i: 329. Thread 84 is running
# i: 332. Thread 90 is running
# i: 333. Thread 67 is running
# i: 334. Thread 64 is running
# i: 335. Thread 61 is running
# i: 336. Thread 68 is running
# i: 343. Thread 66 is running
# i: 340. Thread 60 is running
# i: 338. Thread 57 is running
# i: 341. Thread 63 is running
# i: 342. Thread 65 is running
# i: 339. Thread 62 is running
# i: 337. Thread 69 is running
# i: 344. Thread 89 is running
# i: 354. Thread 78 is running
# i: 355. Thread 71 is running
# i: 345. Thread 76 is running
# i: 346. Thread 70 is running
# i: 347. Thread 73 is running
# i: 348. Thread 80 is running
# i: 349. Thread 91 is running
# i: 350. Thread 72 is running
# i: 352. Thread 75 is running
# i: 353. Thread 77 is running
# i: 351. Thread 48 is running
# i: 356. Thread 83 is running
# i: 358. Thread 85 is running
# i: 357. Thread 87 is running
# i: 362. Thread 82 is running
# i: 364. Thread 84 is running
# i: 360. Thread 88 is running
# i: 359. Thread 86 is running
# i: 361. Thread 81 is running
# i: 363. Thread 79 is running
# i: 365. Thread 90 is running
# i: 368. Thread 61 is running
# i: 367. Thread 64 is running
# i: 366. Thread 67 is running
# i: 369. Thread 68 is running
# i: 374. Thread 65 is running
# i: 373. Thread 63 is running
# i: 375. Thread 62 is running
# i: 371. Thread 60 is running
# i: 370. Thread 66 is running
# i: 372. Thread 57 is running
# i: 376. Thread 69 is running
# i: 377. Thread 89 is running
# i: 378. Thread 78 is running
# i: 379. Thread 71 is running
# i: 386. Thread 75 is running
# i: 385. Thread 72 is running
# i: 382. Thread 73 is running
# i: 381. Thread 70 is running
# i: 383. Thread 80 is running
# i: 380. Thread 76 is running
# i: 384. Thread 91 is running
# i: 387. Thread 77 is running
# i: 388. Thread 48 is running
# i: 389. Thread 83 is running
# i: 394. Thread 88 is running
# i: 391. Thread 87 is running
# i: 392. Thread 82 is running
# i: 390. Thread 85 is running
# i: 397. Thread 79 is running
# i: 396. Thread 81 is running
# i: 393. Thread 84 is running
# i: 395. Thread 86 is running
# i: 398. Thread 90 is running
# i: 399. Thread 61 is running
# i: 400. Thread 64 is running
# i: 401. Thread 67 is running
# i: 402. Thread 68 is running
# i: 405. Thread 62 is running
# i: 403. Thread 65 is running
# i: 404. Thread 63 is running
# i: 406. Thread 60 is running
# i: 408. Thread 57 is running
# i: 407. Thread 66 is running
# i: 409. Thread 69 is running
# i: 410. Thread 89 is running
# i: 411. Thread 78 is running
# i: 414. Thread 72 is running
# i: 412. Thread 71 is running
# i: 413. Thread 75 is running
# i: 417. Thread 80 is running
# i: 419. Thread 91 is running
# i: 418. Thread 76 is running
# i: 415. Thread 73 is running
# i: 416. Thread 70 is running
# i: 420. Thread 77 is running
# i: 421. Thread 48 is running
# i: 422. Thread 83 is running
# i: 424. Thread 87 is running
# i: 425. Thread 82 is running
# i: 423. Thread 88 is running
# i: 428. Thread 81 is running
# i: 429. Thread 84 is running
# i: 431. Thread 90 is running
# i: 426. Thread 85 is running
# i: 427. Thread 79 is running
# i: 430. Thread 86 is running
# i: 434. Thread 61 is running
# i: 432. Thread 64 is running
# i: 433. Thread 67 is running
# i: 435. Thread 68 is running
# i: 436. Thread 62 is running
# i: 439. Thread 60 is running
# i: 438. Thread 63 is running
# i: 437. Thread 65 is running
# i: 440. Thread 57 is running
# i: 441. Thread 66 is running
# i: 442. Thread 69 is running
# i: 443. Thread 89 is running
# i: 444. Thread 78 is running
# i: 447. Thread 75 is running
# i: 448. Thread 80 is running
# i: 446. Thread 71 is running
# i: 455. Thread 83 is running
# i: 445. Thread 72 is running
# i: 453. Thread 77 is running
# i: 452. Thread 70 is running
# i: 451. Thread 73 is running
# i: 449. Thread 91 is running
# i: 450. Thread 76 is running
# i: 454. Thread 48 is running
# i: 456. Thread 87 is running
# i: 457. Thread 82 is running
# i: 458. Thread 88 is running
# i: 461. Thread 90 is running
# i: 462. Thread 85 is running
# i: 459. Thread 81 is running
# i: 460. Thread 84 is running
# i: 463. Thread 79 is running
# i: 464. Thread 86 is running
# i: 466. Thread 74 is running
# i: 465. Thread 61 is running
# i: 467. Thread 64 is running
# i: 468. Thread 67 is running
# i: 469. Thread 68 is running
# i: 473. Thread 65 is running
# i: 472. Thread 63 is running
# i: 475. Thread 66 is running
# i: 471. Thread 60 is running
# i: 470. Thread 62 is running
# i: 474. Thread 57 is running
# i: 476. Thread 69 is running
# i: 477. Thread 89 is running
# i: 487. Thread 91 is running
# i: 478. Thread 78 is running
# i: 479. Thread 75 is running
# i: 482. Thread 83 is running
# i: 488. Thread 76 is running
# i: 483. Thread 72 is running
# i: 480. Thread 80 is running
# i: 481. Thread 71 is running
# i: 484. Thread 77 is running
# i: 485. Thread 70 is running
# i: 489. Thread 48 is running
# i: 490. Thread 87 is running
# i: 486. Thread 73 is running
# i: 491. Thread 82 is running
# i: 497. Thread 79 is running
# i: 492. Thread 88 is running
# i: 493. Thread 90 is running
# i: 494. Thread 85 is running
# i: 498. Thread 86 is running
# i: 496. Thread 84 is running
# i: 495. Thread 81 is running
# i: 499. Thread 74 is running
# i: 502. Thread 67 is running
# i: 500. Thread 61 is running
# i: 501. Thread 64 is running
# i: 503. Thread 68 is running
# i: 504. Thread 65 is running
# i: 506. Thread 66 is running
# i: 507. Thread 60 is running
# i: 508. Thread 62 is running
# i: 509. Thread 57 is running
# i: 505. Thread 63 is running
# i: 510. Thread 69 is running
# i: 521. Thread 70 is running
# i: 511. Thread 89 is running
# i: 516. Thread 76 is running
# i: 517. Thread 72 is running
# i: 518. Thread 80 is running
# i: 519. Thread 71 is running
# i: 513. Thread 78 is running
# i: 520. Thread 77 is running
# i: 514. Thread 75 is running
# i: 512. Thread 91 is running
# i: 515. Thread 83 is running
# i: 522. Thread 48 is running
# i: 523. Thread 87 is running
# i: 524. Thread 73 is running
# i: 527. Thread 88 is running
# i: 532. Thread 81 is running
# i: 525. Thread 82 is running
# i: 529. Thread 85 is running
# i: 526. Thread 79 is running
# i: 528. Thread 90 is running
# i: 531. Thread 84 is running
# i: 530. Thread 86 is running
# i: 533. Thread 74 is running
# i: 536. Thread 64 is running
# i: 535. Thread 61 is running
# i: 534. Thread 67 is running
# i: 540. Thread 60 is running
# i: 537. Thread 68 is running
# i: 539. Thread 66 is running
# i: 542. Thread 57 is running
# i: 538. Thread 65 is running
# i: 543. Thread 63 is running
# i: 541. Thread 62 is running
# i: 544. Thread 69 is running
# i: 545. Thread 70 is running
# i: 548. Thread 72 is running
# i: 549. Thread 80 is running
# i: 550. Thread 71 is running
# i: 551. Thread 78 is running
# i: 552. Thread 77 is running
# i: 556. Thread 48 is running
# i: 553. Thread 75 is running
# i: 554. Thread 91 is running
# i: 562. Thread 85 is running
# i: 555. Thread 83 is running
# i: 546. Thread 89 is running
# i: 557. Thread 87 is running
# i: 558. Thread 73 is running
# i: 547. Thread 76 is running
# i: 559. Thread 88 is running
# i: 563. Thread 79 is running
# i: 560. Thread 81 is running
# i: 564. Thread 90 is running
# i: 561. Thread 82 is running
# i: 565. Thread 84 is running
# i: 566. Thread 86 is running
# i: 567. Thread 74 is running
# i: 569. Thread 61 is running
# i: 568. Thread 64 is running
# i: 570. Thread 67 is running
# i: 571. Thread 60 is running
# i: 576. Thread 63 is running
# i: 574. Thread 57 is running
# i: 572. Thread 68 is running
# i: 575. Thread 65 is running
# i: 577. Thread 62 is running
# i: 573. Thread 66 is running
# i: 578. Thread 69 is running
# i: 579. Thread 70 is running
# i: 580. Thread 72 is running
# i: 581. Thread 80 is running
# i: 582. Thread 71 is running
# i: 583. Thread 78 is running
# i: 585. Thread 48 is running
# i: 584. Thread 77 is running
# i: 586. Thread 75 is running
# i: 591. Thread 87 is running
# i: 588. Thread 85 is running
# i: 587. Thread 91 is running
# i: 589. Thread 83 is running
# i: 590. Thread 89 is running
# i: 599. Thread 84 is running
# i: 592. Thread 73 is running
# i: 597. Thread 90 is running
# i: 593. Thread 76 is running
# i: 594. Thread 88 is running
# i: 595. Thread 79 is running
# i: 596. Thread 81 is running
# i: 598. Thread 82 is running
# i: 600. Thread 86 is running
# i: 601. Thread 74 is running
# i: 602. Thread 61 is running
# i: 603. Thread 64 is running
# i: 604. Thread 67 is running
# i: 605. Thread 60 is running
# i: 611. Thread 66 is running
# i: 606. Thread 63 is running
# i: 607. Thread 57 is running
# i: 608. Thread 68 is running
# i: 609. Thread 65 is running
# i: 610. Thread 62 is running
# i: 612. Thread 69 is running
# i: 613. Thread 70 is running
# i: 617. Thread 78 is running
# i: 616. Thread 71 is running
# i: 615. Thread 80 is running
# i: 614. Thread 72 is running
# i: 618. Thread 48 is running
# i: 619. Thread 77 is running
# i: 620. Thread 75 is running
# i: 622. Thread 85 is running
# i: 624. Thread 83 is running
# i: 623. Thread 91 is running
# i: 621. Thread 87 is running
# i: 626. Thread 84 is running
# i: 632. Thread 81 is running
# i: 631. Thread 79 is running
# i: 627. Thread 73 is running
# i: 625. Thread 89 is running
# i: 628. Thread 90 is running
# i: 629. Thread 76 is running
# i: 630. Thread 88 is running
# i: 634. Thread 86 is running
# i: 633. Thread 82 is running
# i: 635. Thread 74 is running
# i: 638. Thread 67 is running
# i: 636. Thread 61 is running
# i: 637. Thread 64 is running
# i: 641. Thread 63 is running
# i: 639. Thread 60 is running
# i: 643. Thread 68 is running
# i: 644. Thread 65 is running
# i: 642. Thread 57 is running
# i: 640. Thread 66 is running
# i: 645. Thread 62 is running
# i: 646. Thread 69 is running
# i: 647. Thread 70 is running
# i: 648. Thread 78 is running
# i: 650. Thread 80 is running
# i: 649. Thread 71 is running
# i: 651. Thread 72 is running
# i: 652. Thread 48 is running
# i: 653. Thread 77 is running
# i: 654. Thread 75 is running
# i: 655. Thread 85 is running
# i: 663. Thread 89 is running
# i: 656. Thread 83 is running
# i: 657. Thread 91 is running
# i: 658. Thread 87 is running
# i: 662. Thread 73 is running
# i: 659. Thread 84 is running
# i: 664. Thread 90 is running
# i: 666. Thread 88 is running
# i: 665. Thread 76 is running
# i: 661. Thread 79 is running
# i: 660. Thread 81 is running
# i: 667. Thread 86 is running
# i: 668. Thread 82 is running
# i: 669. Thread 74 is running
# i: 670. Thread 67 is running
# i: 672. Thread 64 is running
# i: 671. Thread 61 is running
# i: 673. Thread 63 is running
# i: 674. Thread 60 is running
# i: 676. Thread 65 is running
# i: 677. Thread 57 is running
# i: 675. Thread 68 is running
# i: 678. Thread 66 is running
# i: 679. Thread 62 is running
# i: 680. Thread 69 is running
# i: 681. Thread 70 is running
# i: 686. Thread 48 is running
# i: 687. Thread 77 is running
# i: 688. Thread 75 is running
# i: 683. Thread 80 is running
# i: 682. Thread 78 is running
# i: 684. Thread 71 is running
# i: 685. Thread 72 is running
# i: 689. Thread 85 is running
# i: 690. Thread 89 is running
# i: 692. Thread 91 is running
# i: 693. Thread 87 is running
# i: 694. Thread 73 is running
# i: 696. Thread 90 is running
# i: 699. Thread 79 is running
# i: 701. Thread 86 is running
# i: 700. Thread 81 is running
# i: 691. Thread 83 is running
# i: 698. Thread 76 is running
# i: 697. Thread 88 is running
# i: 695. Thread 84 is running
# i: 702. Thread 82 is running
# i: 703. Thread 72 is running
# i: 705. Thread 89 is running
# i: 704. Thread 85 is running
# i: 706. Thread 91 is running
# i: 707. Thread 87 is running
# i: 713. Thread 83 is running
# i: 708. Thread 73 is running
# i: 710. Thread 79 is running
# i: 712. Thread 81 is running
# i: 709. Thread 90 is running
# i: 711. Thread 86 is running
# i: 714. Thread 76 is running
# i: 715. Thread 88 is running
# i: 716. Thread 84 is running
# i: 717. Thread 82 is running
# i: 718. Thread 71 is running
# i: 719. Thread 72 is running
# i: 720. Thread 89 is running
# i: 723. Thread 87 is running
# i: 722. Thread 91 is running
# i: 725. Thread 73 is running
# i: 726. Thread 79 is running
# i: 721. Thread 85 is running
# i: 731. Thread 88 is running
# i: 732. Thread 84 is running
# i: 728. Thread 90 is running
# i: 724. Thread 83 is running
# i: 733. Thread 82 is running
# i: 730. Thread 76 is running
# i: 727. Thread 81 is running
# i: 729. Thread 86 is running
# i: 734. Thread 71 is running
# i: 735. Thread 72 is running
# i: 736. Thread 89 is running
# i: 737. Thread 87 is running
# i: 738. Thread 91 is running
# i: 741. Thread 85 is running
# i: 739. Thread 73 is running
# i: 748. Thread 81 is running
# i: 742. Thread 88 is running
# i: 744. Thread 90 is running
# i: 740. Thread 79 is running
# i: 745. Thread 83 is running
# i: 747. Thread 76 is running
# i: 743. Thread 84 is running
# i: 746. Thread 82 is running
# i: 749. Thread 86 is running
# i: 750. Thread 71 is running
# i: 751. Thread 72 is running
# i: 752. Thread 89 is running
# i: 753. Thread 87 is running
# i: 759. Thread 90 is running
# i: 762. Thread 76 is running
# i: 755. Thread 85 is running
# i: 760. Thread 79 is running
# i: 761. Thread 83 is running
# i: 754. Thread 91 is running
# i: 757. Thread 81 is running
# i: 756. Thread 73 is running
# i: 758. Thread 88 is running
# i: 765. Thread 86 is running
# i: 763. Thread 84 is running
# i: 764. Thread 82 is running
# i: 766. Thread 71 is running
# i: 767. Thread 72 is running
# i: 768. Thread 89 is running
# i: 769. Thread 87 is running
# i: 770. Thread 90 is running
# i: 778. Thread 88 is running
# i: 771. Thread 76 is running
# i: 772. Thread 85 is running
# i: 773. Thread 79 is running
# i: 775. Thread 91 is running
# i: 777. Thread 73 is running
# i: 776. Thread 81 is running
# i: 774. Thread 83 is running
# i: 779. Thread 86 is running
# i: 780. Thread 84 is running
# i: 781. Thread 82 is running
# i: 782. Thread 71 is running
# i: 783. Thread 72 is running
# i: 784. Thread 89 is running
# i: 785. Thread 87 is running
# i: 787. Thread 88 is running
# i: 789. Thread 85 is running
# i: 791. Thread 91 is running
# i: 788. Thread 76 is running
# i: 786. Thread 90 is running
# i: 790. Thread 79 is running
# i: 792. Thread 73 is running
# i: 793. Thread 81 is running
# i: 794. Thread 83 is running
# i: 795. Thread 86 is running
# i: 796. Thread 84 is running
# i: 797. Thread 82 is running
# i: 798. Thread 71 is running
# i: 799. Thread 78 is running
# i: 800. Thread 72 is running
# i: 802. Thread 87 is running
# i: 801. Thread 89 is running
# i: 803. Thread 88 is running
# i: 804. Thread 85 is running
# i: 805. Thread 91 is running
# i: 806. Thread 76 is running
# i: 807. Thread 90 is running
# i: 809. Thread 73 is running
# i: 808. Thread 79 is running
# i: 810. Thread 81 is running
# i: 811. Thread 83 is running
# i: 812. Thread 86 is running
# i: 813. Thread 84 is running
# i: 814. Thread 82 is running
# i: 816. Thread 78 is running
# i: 815. Thread 71 is running
# i: 817. Thread 72 is running
# i: 818. Thread 87 is running
# i: 820. Thread 88 is running
# i: 819. Thread 89 is running
# i: 821. Thread 85 is running
# i: 822. Thread 91 is running
# i: 823. Thread 76 is running
# i: 826. Thread 79 is running
# i: 824. Thread 90 is running
# i: 825. Thread 73 is running
# i: 827. Thread 81 is running
# i: 828. Thread 83 is running
# i: 829. Thread 86 is running
# i: 830. Thread 84 is running
# i: 831. Thread 82 is running
# i: 832. Thread 78 is running
# i: 833. Thread 71 is running
# i: 834. Thread 72 is running
# i: 835. Thread 87 is running
# i: 839. Thread 91 is running
# i: 836. Thread 88 is running
# i: 837. Thread 89 is running
# i: 838. Thread 85 is running
# i: 840. Thread 76 is running
# i: 842. Thread 90 is running
# i: 841. Thread 79 is running
# i: 843. Thread 73 is running
# i: 844. Thread 81 is running
# i: 845. Thread 83 is running
# i: 846. Thread 86 is running
# i: 847. Thread 84 is running
# i: 848. Thread 82 is running
# i: 849. Thread 78 is running
# i: 850. Thread 71 is running
# i: 852. Thread 87 is running
# i: 853. Thread 91 is running
# i: 851. Thread 72 is running
# i: 855. Thread 89 is running
# i: 854. Thread 88 is running
# i: 856. Thread 85 is running
# i: 857. Thread 76 is running
# i: 858. Thread 90 is running
# i: 860. Thread 73 is running
# i: 859. Thread 79 is running
# i: 865. Thread 82 is running
# i: 861. Thread 81 is running
# i: 862. Thread 83 is running
# i: 863. Thread 86 is running
# i: 864. Thread 84 is running
# i: 867. Thread 71 is running
# i: 866. Thread 78 is running
# i: 872. Thread 88 is running
# i: 868. Thread 87 is running
# i: 869. Thread 91 is running
# i: 870. Thread 72 is running
# i: 871. Thread 89 is running
# i: 873. Thread 85 is running
# i: 875. Thread 90 is running
# i: 874. Thread 76 is running
# i: 876. Thread 73 is running
# i: 877. Thread 79 is running
# i: 878. Thread 82 is running
# i: 879. Thread 81 is running
# i: 880. Thread 83 is running
# i: 881. Thread 86 is running
# i: 882. Thread 84 is running
# i: 883. Thread 71 is running
# i: 884. Thread 78 is running
# i: 885. Thread 88 is running
# i: 887. Thread 91 is running
# i: 886. Thread 87 is running
# i: 892. Thread 76 is running
# i: 894. Thread 79 is running
# i: 889. Thread 89 is running
# i: 891. Thread 90 is running
# i: 890. Thread 85 is running
# i: 893. Thread 73 is running
# i: 888. Thread 72 is running
# i: 895. Thread 82 is running
# i: 896. Thread 81 is running
# i: 897. Thread 83 is running
# i: 898. Thread 86 is running
# i: 899. Thread 84 is running
# i: 901. Thread 78 is running
# i: 900. Thread 71 is running
# i: 902. Thread 88 is running
# i: 903. Thread 91 is running
# i: 909. Thread 85 is running
# i: 910. Thread 73 is running
# i: 911. Thread 72 is running
# i: 904. Thread 87 is running
# i: 905. Thread 76 is running
# i: 906. Thread 79 is running
# i: 907. Thread 89 is running
# i: 908. Thread 90 is running
# i: 912. Thread 82 is running
# i: 913. Thread 81 is running
# i: 914. Thread 83 is running
# i: 915. Thread 86 is running
# i: 916. Thread 84 is running
# i: 917. Thread 78 is running
# i: 930. Thread 63 is running
# i: 929. Thread 60 is running
# i: 928. Thread 65 is running
# i: 920. Thread 77 is running
# i: 923. Thread 68 is running
# i: 918. Thread 80 is running
# i: 921. Thread 48 is running
# i: 919. Thread 75 is running
# i: 925. Thread 62 is running
# i: 933. Thread 74 is running
# i: 927. Thread 57 is running
# i: 931. Thread 61 is running
# i: 932. Thread 64 is running
# i: 926. Thread 66 is running
# i: 922. Thread 70 is running
# i: 924. Thread 69 is running
# i: 935. Thread 71 is running
# i: 934. Thread 67 is running
# i: 938. Thread 94 is running
# i: 936. Thread 92 is running
# i: 939. Thread 95 is running
# i: 937. Thread 93 is running
# i: 941. Thread 91 is running
# i: 940. Thread 88 is running
# i: 942. Thread 85 is running
# i: 943. Thread 73 is running
# i: 949. Thread 90 is running
# i: 946. Thread 76 is running
# i: 948. Thread 89 is running
# i: 947. Thread 79 is running
# i: 945. Thread 87 is running
# i: 944. Thread 72 is running
# i: 950. Thread 82 is running
# i: 954. Thread 84 is running
# i: 951. Thread 81 is running
# i: 952. Thread 83 is running
# i: 953. Thread 86 is running
# i: 955. Thread 78 is running
# i: 957. Thread 60 is running
# i: 958. Thread 65 is running
# i: 959. Thread 77 is running
# i: 960. Thread 68 is running
# i: 961. Thread 80 is running
# i: 962. Thread 48 is running
# i: 965. Thread 74 is running
# i: 966. Thread 57 is running
# i: 964. Thread 62 is running
# i: 956. Thread 63 is running
# i: 967. Thread 61 is running
# i: 963. Thread 75 is running
# i: 970. Thread 70 is running
# i: 968. Thread 64 is running
# i: 969. Thread 66 is running
# i: 971. Thread 69 is running
# i: 972. Thread 71 is running
# i: 973. Thread 67 is running
# i: 974. Thread 94 is running
# i: 975. Thread 92 is running
# i: 976. Thread 95 is running
# i: 977. Thread 93 is running

# %%
using System;
using System.Collections.Concurrent;
using System.Threading;
using System.Threading.Tasks;

AsyncLocal<int> capturedValue = new ();

for (int i = 0; i < 1000; i++)
{
    capturedValue.Value = i; // Create a local variable and assign the value of i to it. 
    // Every work in the queue will have its own copy of the capturedValue

    MyThreadPool.QueueUserWorkItem(delegate{
        Thread.Sleep(1000);
        Console.WriteLine($"i: {capturedValue.Value}. Thread {Thread.CurrentThread.ManagedThreadId} is running");
    });
}

static class MyThreadPool
{
    private static readonly BlockingCollection<(Action, ExecutionContext?)> s_workItems = new ();
    // to store things in the concurrent queue but when I want to that I want to block the thread until there is something to do.
    // the threads in the tread pool are going to try to take things from the queue to process it, if nothing is there just wait 
    public static void QueueUserWorkItem(Action action)
    {
        s_workItems.Add((action, ExecutionContext.Capture()));
    }
    static MyThreadPool()
    {
        for (int i = 0; i < Environment.ProcessorCount; i++)
        {
            new Thread(()=> {
              while(true){
                (Action workItem, ExecutionContext? context) = s_workItems.Take();
                if(context is null){
                  workItem();
                }else{
                  ExecutionContext.Run(context, delegate {workItem();}, null);
                  ExecutionContext.Run(context, (object? state) => ((Action)state!).Invoke(), workItem);
                }

              }
            }){IsBackground = true}.Start();
        }
    }
}

# %% [markdown]
# ### Asynchronous
# Can have asynchrony without concurrency. Asynchrony allows tasks to be paused and resumed.
#
# <img src="https://i.gyazo.com/a4748bd9497eb9700eb9abcd0e948fb7.png" alt="Description of the image">
#
# Queueing up tasks to run back on the very place they were called from. It is asynchronous invocation but not necessarily concurrency.
#
# ---
# ### Concurrency
# Can't have concurrency without asynchrony.
#
# Concurrency involves multiple tasks making progress simultaneously, which inherently requires asynchrony to manage the execution of these tasks without blocking each other.
#
# <img src="https://i.gyazo.com/1bd5a4d7ee3865521bb5e1d6e8a7c4d8.png" alt="Description of the image">
#
# Line 5 and 7 are running at the same time.
